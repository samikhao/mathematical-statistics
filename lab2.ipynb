# %% [markdown]
# Лабораторная работа 2. Вариант 2. Баркова Александра 408223

# %% [markdown]
# Для равномерного распределения на отрезке [0, θ] по выборке:
# 1. Найти точечную оценку параметра θ методом максимального правдоподобия
# 2. Построить доверительный интервал уровня доверия α = 95%

# %% [markdown]
# Вывод формул представлен на картинках ниже

# %% [markdown]
# <img src="..." width="500"/>

# %% [markdown]
# <img src="..." width="500"/>

# %%
data = [
    0.0367, 0.032, 0.2989, 0.2454, 0.0383,
    0.2198, 0.0942, 0.0807, 0.2893, 0.1763,
    0.0222, 0.032, 0.009, 0.2412, 0.088,
    0.2408, 0.2511, 0.24, 0.1709, 0.1257,
    0.0687, 0.2442, 0.0444, 0.0525, 0.2095,
    0.1245, 0.1042, 0.1003, 0.1425, 0.2809,
    0.1493, 0.2031, 0.2606, 0.2957, 0.2566,
    0.1347, 0.051, 0.2916, 0.0545, 0.0695,
    0.0506, 0.2781, 0.0733, 0.0778, 0.2075,
    0.0661, 0.0153, 0.0585, 0.1006, 0.0484
]

theta = max(data)
print('Точечная оценка:', theta)

n = len(data)
x_mean = sum(data) / n
c = 1.96
T1 = ((3 * n) ** 0.5 * 2 * x_mean) / ((3 * n) ** 0.5 + c)
T2 = ((3 * n) ** 0.5 * 2 * x_mean) / ((3 * n) ** 0.5 - c)
print(f"Доверительный интервал: ({round(T1, 4)}; {round(T2, 4)})")
# Out:
# Точечная оценка: 0.2989
# Доверительный интервал: (0.243; 0.3356)
